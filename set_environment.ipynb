# %% [markdown]
# <a href="https://colab.research.google.com/github/brianchen989/learnAi/blob/main/set_environment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Tue Nov  4 02:40:51 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   64C    P8             12W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/GrandmaCan/ML/main/Resgression/Salary_Data.csv"
data = pd.read_csv(url)
data
#y = a*x + b
x = data["YearsExperience"]
y = data["Salary"]

# %%
# !pip install wget
import wget
wget.download("https://github.com/GrandmaCan/ML/raw/main/Resgression/ChineseFont.ttf")
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=1edaf11378f20b46e779d21b1d1365a64c70c82ebe7a07117e2b060f130ceb0e
#   Stored in directory: /root/.cache/pip/wheels/01/46/3b/e29ffbe4ebe614ff224bad40fc6a5773a67a163251585a13a9
# Successfully built wget
# ...
# 'ChineseFont.ttf'

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.font_manager import fontManager
fontManager.addfont("ChineseFont.ttf")
mpl.rc("font",family = "ChineseFont")

#draw x,y
plt.scatter(x,y,marker="x" , color = "yellow")
plt.title("年資--薪水")
plt.xlabel("年資")
plt.ylabel("薪水(thousands)")
plt.show()

# %%
a = 0
b = 0
def plotPred(a,b):
  yPreb = a*x+b
  plt.scatter(x,y,marker="x" , color = "blue",label = "true data")
  plt.title("年資--薪水")
  plt.xlabel("年資")
  plt.ylabel("薪水(thousands)")
  plt.plot(x,yPreb,color = "red",label = "predict line")
  plt.xlim([0,12])
  plt.ylim([-60,130])
  plt.legend()
  plt.show()
plotPred(10,30)

# %%
from ipywidgets import interact
interact(plotPred,a=(-100,100),b=(-100,100))
# Out:
# interactive(children=(IntSlider(value=0, description='a', min=-100), IntSlider(value=0, description='b', min=-…
# <function __main__.plotPred(a, b)>
