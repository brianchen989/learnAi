# %% [markdown]
# <a href="https://colab.research.google.com/github/brianchen989/learnAi/blob/main/const_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/GrandmaCan/ML/main/Resgression/Salary_Data.csv"
data = pd.read_csv(url)
data
#y = a*x + b
x = data["YearsExperience"]
y = data["Salary"]

# %%
a = 0
b = 0


def computeConst(x,y,a,b):
  yPred = a * x + b
  cost = (y - yPred)**2
  cost = cost.sum()/len(x)
  return cost

# %%
computeConst(x,y,10,10)
# Out:
# np.float64(227.88121212121214)

# %%
#b=0 , a = -100~100
costs = []
for a in range(-100,100):
    cost = computeConst(x,y,a,0)
    costs.append(cost)

# %%
import matplotlib.pyplot as plt
#plt.scatter(range(-100,100),costs)
plt.plot(range(-100,100),costs)
plt.title("Cost Function when b = o")
plt.xlabel("a")
plt.ylabel("Cost")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
aS = np.arange(-100,101)
bS = np.arange(-100,101)
costs = np.zeros((len(aS),len(bS)))
i = 0
for a in aS:
  j = 0
  for b in bS:
      costs[i,j] = computeConst(x,y,a,b)
      j = j + 1
  i = i + 1
costs
# Out:
# array([[543097.74787879, 541777.28121212, 540458.81454545, ...,
#         320651.34787879, 319726.88121212, 318804.41454545],
#        [534727.50939394, 533416.80636364, 532108.10333333, ...,
#         314214.30939394, 313299.60636364, 312386.90333333],
#        [526422.82181818, 525121.88242424, 523822.9430303 , ...,
#         307842.82181818, 306937.88242424, 306034.9430303 ],
#        ...,
#        [164229.90787879, 164842.64121212, 165457.37454545, ...,
#         324557.10787879, 325565.84121212, 326576.57454545],
#        [168838.74939394, 169461.24636364, 170085.74333333, ...,
#         331099.14939394, 332117.64636364, 333138.14333333],
#        [173513.14181818, 174145.40242424, 174779.6630303 , ...,
#         337706.74181818, 338735.00242424, 339765.2630303 ]])

# %%
ax = plt.axes(projection = "3d")
#ax.view_init(60,35)旋轉圖
plt.figure(figsize = (10,10))
ax.xaxis.set_pane_color((1,1,1))
ax.yaxis.set_pane_color((1,1,1))
ax.zaxis.set_pane_color((1,1,1))
b_grid,a_grid = np.meshgrid(bS,aS)#製作二圍網格
ax.plot_surface(a_grid , b_grid , costs , cmap = "Spectral_r"  , alpha = 0.7 )#曲面圖(cmap = "Spectral_r" 換顏色)(alpha = 0.7透明度 )
ax.set_title("a&b's  cost function ")
ax.set_xlabel("a")
ax.set_ylabel("b")
ax.set_zlabel("Cost")
a_index ,b_index = np.where(costs == np.min(costs))
print(a_index ,b_index , np.min(costs))
print(f"when a ={aS[a_index]} ,b = {bS[b_index]},there is a min{costs[a_index,b_index]} ")
ax.scatter(aS[a_index] , bS[b_index] ,costs[a_index,b_index],color = "red")
plt.show()
# Out:
# [109] [129] 32.6948484848485
# when a =[9] ,b = [29],there is a min[32.69484848]
